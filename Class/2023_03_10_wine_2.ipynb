# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
# 데이터 로드 및 전처리
wine = load_wine()

# x에 data를 넣고 즉(feature_names), y에 target을 넣는거임(kind)
x = pd.DataFrame(data = wine.data, columns = wine.feature_names)
y = pd.DataFrame(wine.target, columns = ['kind'])

# StandardScaler로 데이터 전처리
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
y
# Out:
#      kind
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ..    ...
# 173     2
# 174     2
# 175     2
# 176     2
# 177     2
#
# [178 rows x 1 columns]

# %%
data = pd.concat([x, y], axis = 1)

# %%
data
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
data.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'kind'],
#       dtype='object')

# %%
# 그래프
import seaborn as sns
sns.countplot(data = data, x="kind")
plt.xlabel("kind")
plt.ylabel("num")
plt.title("Kind_num")
# Out:
# Text(0.5, 1.0, 'Kind_num')

# %%
# 산점도
# 막대 그래프 // sns.histplot(data=data, x='hue')
data.plot(kind='scatter', x = 'kind', y = 'color_intensity', title = '2. test')
plt.show()

# %%
# 산점도
data.plot(kind='scatter', x = 'kind', y = 'hue', title = '3. test')
plt.show()

# %%
# 산점도
data.plot(kind='scatter', x = 'color_intensity', y = 'hue', title = '4. test')
plt.show()

# %%
# 5번 과제
sns.set_theme(style="whitegrid")
sns.boxplot(x="color_intensity", data=data, palette="Set3")
plt.title("color_intensity")
plt.show()

# %%
# 5번_2 과제
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
data.hist(ax = ax)
plt.show()
# Out:
# <ipython-input-31-995ecab194fb>:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.hist(ax = ax)

# %%
# 결측값 확인
data.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# kind                            0
# dtype: int64

# %%
# kind drop 하기
x = data.drop('kind', axis = 1)
x.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
sns.pairplot(data, vars=['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash'], hue ='kind')
plt.show()
